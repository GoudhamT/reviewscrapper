# %%
# steps:
""" 1) to created new environment
            conda create -n reviewscrapper python==3.7.4 
    2) activate created environment
            conda activate reviewscrapper
    3) to inside DIR where requirement is saved
             pip install -r requirements.txt
    4) install jupyter notebook for created environment
             pip install jupyter 
    5) run jupyter notebook
           jupyter notebook
    6) now call below commands, it will run without any error
      """

# %%
from flask import Flask, render_template,jsonify,request
import requests
from flask_cors import CORS,cross_origin
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
whatYouWantToSearch = input(str("Please enter anythin to search in Flipkart"))
# Out:
# Please enter anythin to search in Flipkartiphone

# %%
flipkart_serach_url = 'https://www.flipkart.com/search?q='+whatYouWantToSearch

# %%
flipkart_serach_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
uClient = uReq(flipkart_serach_url)

# %%
flipkart_page = uClient.read()

# %%
uClient.close()

# %%
flipkart_html = bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkart_serach_boxes = flipkart_html.find_all('div',{'class': '_1AtVbE col-12-12'})

# %%
del flipkart_serach_boxes[0]

# %%
flipkart_detail_ref = flipkart_serach_boxes[0].div.div.div.a['href']
flipkart_detail_ref
# Out:
# '/apple-iphone-12-blue-128-gb/p/itm02853ae92e90a?pid=MOBFWBYZKPTZF9VG&lid=LSTMOBFWBYZKPTZF9VG6GMIFT&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=26b8f717-9143-45ab-87a9-d9036f8f94e4.MOBFWBYZKPTZF9VG.SEARCH&ppt=None&ppn=None&ssid=09guqy7pkw0000001628077143127&qH=0b3f45b266a97d70'

# %%
flipkart_detail_page = 'https://www.flipkart.com'+flipkart_detail_ref
flipkart_detail_page
# Out:
# 'https://www.flipkart.com/apple-iphone-12-blue-128-gb/p/itm02853ae92e90a?pid=MOBFWBYZKPTZF9VG&lid=LSTMOBFWBYZKPTZF9VG6GMIFT&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=26b8f717-9143-45ab-87a9-d9036f8f94e4.MOBFWBYZKPTZF9VG.SEARCH&ppt=None&ppn=None&ssid=09guqy7pkw0000001628077143127&qH=0b3f45b266a97d70'

# %%
uClient = uReq(flipkart_detail_page)

# %%
flipkart_single_page = uClient.read()

# %%
uClient.close()

# %%
flipkart_single_page_html = bs(flipkart_single_page,'html.parser')

# %%
flipkart_single_page_html
# Out:
# <!DOCTYPE html>
# ...

# %%
product_review_heading = flipkart_single_page_html.find_all('div',{'class':'_16PBlm'})

# %%
product_review_heading[0].div.div.p.text
# Out:
# 'Must buy!'

# %%
product_rating = product_review_heading[0].div.div.div.div.text

# %%
product_rating
# Out:
# '5'

# %%
product_review = product_review_heading[0].div.div.find_all('div',{'class':""})[0].div.text
# product_review_desc[0].div.text

# %%
product_review
# Out:
# 'Delightful phone, the phone is just a peice of art, sleek, eye catchy, super fast and got everything u need...best one available'

# %%
product_review_heading[0].div.div.find_all('p',{'class':'_2sc7ZR _2V5EHH'})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Pranjal Dwivedi</p>]

# %%
name = product_review_heading[0].div.div.find_all('p',{'class':'_2sc7ZR _2V5EHH'})[0].text

# %%
name
# Out:
# 'Pranjal Dwivedi'

# %%
product_name = flipkart_single_page_html.find_all('div',{'class':'aMaAEs'})[0].div.h1.text

# %%
product_name
# Out:
# 'APPLE iPhone 12 (Blue, 128 GB)'
